# %% [markdown]
# # Convert Excel to csv files with format
# This notebook converts all Excel (.xlsx) files in the /xlsx_files directory to CSV files, replacing 'Unnamed' columns with blank spaces.

# %%
import os
import pandas as pd

# %%
current_directory = os.getcwd()
current_directory
# Out:
# 'c:\\Users\\PLLOBET.DISTFORM\\Desktop\\UdL\\TFM\\csv-parser'

# %% [markdown]
# Create 'output' directory if it does not exist

# %%
output_directory = os.path.join(current_directory, 'output')
os.makedirs(output_directory, exist_ok=True)
os.listdir(current_directory)
# Out:
# ['format_csv.ipynb', 'output', 'venv', 'xlsx_files']

# %% [markdown]
# Iterates through all the files in the current directory.
# Initializes a list to store the names of converted files.

# %%
# Initializes a list to store the names of converted files
converted_files = []

# Defines the directory where the .xlsx files are located
xlsx_directory = os.path.join(current_directory, 'xlsx_files')

# Iterates through all the files in the /xlsx_files directory
for filename in os.listdir(xlsx_directory):
    if filename.endswith('.xlsx'):
        file_path = os.path.join(xlsx_directory, filename)
        xlsx_data = pd.read_excel(file_path)

        xlsx_data.dropna(axis=1, how='all', inplace=True)

        # Replaces 'Unnamed' columns with ' '
        xlsx_data.columns = [col if 'Unnamed' not in col else ' ' for col in xlsx_data.columns]

        print(f"Table after replacing 'Unnamed' columns with spaces for {filename}:")
        print(xlsx_data)

        # Renames columns to remove spaces and special characters
        xlsx_data.columns = [col.strip().replace(' ', '_').replace('-', '_') for col in xlsx_data.columns]

        csv_filename = f"{os.path.splitext(filename)[0]}.csv"
        csv_file_path = os.path.join(output_directory, csv_filename)

        xlsx_data.to_csv(csv_file_path, index=False, encoding='utf-8')

        converted_files.append(csv_filename)

        print(f"Converted: {filename} to {csv_filename} in the 'output' folder")
# Out:
# Table after replacing 'Unnamed' columns with spaces for Abatidores.xlsx:
#        ItemCode                                           ItemName  \
# 0      0CHAT001                                  Chatarra INOX 304
# 1      0CHAT002                                           Chatarra
# 2      0CHAT003                            Chatarra INOX FERRITICO
# 3      0CHAT005                               Carton para reciclar
# 4      0CHAT006                             Plástico para reciclar
# ...         ...                                                ...
# 23623  VMRA64GN  Vitrina Buffet refrigerada recta mural  con pu...
# 23624  VMRT03GN  Vitrina Buffet refrigerada recta mural con ter...
# 23625  VMRT04GN  Vitrina Buffet refrigerada recta mural  con te...
# 23626  VRE00016  Termómetro analógico redondo, escala 0-120º  M...
# 23627  ZUMFERIA                       Zumos ecologicos para ferias
#
#                                                  English  \
# 0                                         Scrap INOX 304
# 1                                                  Scrap
# 2                         FERRITIC STAINLESS STEEL scrap
# 3                                   Cardboard to recycle
# 4                                  Plastic for recycling
# ...                                                  ...
# 23623                                                NaN
# 23624  Refrigerated straight wall buffet display cabi...
# 23625  Refrigerated straight wall buffet display cabi...
# 23626  Round analog thermometer, scale 0-120º Mod. IM...
# 23627                           Organic juices for fairs
#
#                                                   French English (UK)
# 0                                     Ferraille INOX 304          NaN
# 1                                             Abandonner          NaN
# 2                  Déchets d'ACIER INOXYDABLE FERRITIQUE          NaN
# 3                                      Carton à recycler          NaN
# 4                                   Plastique à recycler          NaN
# ...                                                  ...          ...
# 23623                                                NaN          NaN
# 23624  Vitrine buffet réfrigéré à paroi droite avec t...          NaN
# 23625  Vitrine buffet droit réfrigéré avec thermo-rid...          NaN
# 23626  Thermomètre analogique rond, échelle 0-120º Mo...          NaN
# 23627                                Jus bio pour foires          NaN
#
# [23628 rows x 5 columns]
# Converted: Abatidores.xlsx to Abatidores.csv in the 'output' folder
# Table after replacing 'Unnamed' columns with spaces for Envasadoras.xlsx:
#        ItemCode                                           ItemName  \
# 0      0CHAT001                                  Chatarra INOX 304
# 1      0CHAT002                                           Chatarra
# 2      0CHAT003                            Chatarra INOX FERRITICO
# 3      0CHAT005                               Carton para reciclar
# 4      0CHAT006                             Plástico para reciclar
# ...         ...                                                ...
# 23623  VMRA64GN  Vitrina Buffet refrigerada recta mural  con pu...
# 23624  VMRT03GN  Vitrina Buffet refrigerada recta mural con ter...
# 23625  VMRT04GN  Vitrina Buffet refrigerada recta mural  con te...
# 23626  VRE00016  Termómetro analógico redondo, escala 0-120º  M...
# 23627  ZUMFERIA                       Zumos ecologicos para ferias
#
#                                                  English  \
# 0                                         Scrap INOX 304
# 1                                                  Scrap
# 2                         FERRITIC STAINLESS STEEL scrap
# 3                                   Cardboard to recycle
# 4                                  Plastic for recycling
# ...                                                  ...
# 23623                                                NaN
# 23624  Refrigerated straight wall buffet display cabi...
# 23625  Refrigerated straight wall buffet display cabi...
# 23626  Round analog thermometer, scale 0-120º Mod. IM...
# 23627                           Organic juices for fairs
#
#                                                   French English (UK)
# 0                                     Ferraille INOX 304          NaN
# 1                                             Abandonner          NaN
# 2                  Déchets d'ACIER INOXYDABLE FERRITIQUE          NaN
# 3                                      Carton à recycler          NaN
# 4                                   Plastique à recycler          NaN
# ...                                                  ...          ...
# 23623                                                NaN          NaN
# 23624  Vitrine buffet réfrigéré à paroi droite avec t...          NaN
# 23625  Vitrine buffet droit réfrigéré avec thermo-rid...          NaN
# 23626  Thermomètre analogique rond, échelle 0-120º Mo...          NaN
# 23627                                Jus bio pour foires          NaN
#
# [23628 rows x 5 columns]
# Converted: Envasadoras.xlsx to Envasadoras.csv in the 'output' folder
# Table after replacing 'Unnamed' columns with spaces for Hornos.xlsx:
#        ItemCode                                           ItemName  \
# 0      0CHAT001                                  Chatarra INOX 304
# 1      0CHAT002                                           Chatarra
# 2      0CHAT003                            Chatarra INOX FERRITICO
# 3      0CHAT005                               Carton para reciclar
# 4      0CHAT006                             Plástico para reciclar
# ...         ...                                                ...
# 23623  VMRA64GN  Vitrina Buffet refrigerada recta mural  con pu...
# 23624  VMRT03GN  Vitrina Buffet refrigerada recta mural con ter...
# 23625  VMRT04GN  Vitrina Buffet refrigerada recta mural  con te...
# 23626  VRE00016  Termómetro analógico redondo, escala 0-120º  M...
# 23627  ZUMFERIA                       Zumos ecologicos para ferias
#
#                                                  English  \
# 0                                         Scrap INOX 304
# 1                                                  Scrap
# 2                         FERRITIC STAINLESS STEEL scrap
# 3                                   Cardboard to recycle
# 4                                  Plastic for recycling
# ...                                                  ...
# 23623                                                NaN
# 23624  Refrigerated straight wall buffet display cabi...
# 23625  Refrigerated straight wall buffet display cabi...
# 23626  Round analog thermometer, scale 0-120º Mod. IM...
# 23627                           Organic juices for fairs
#
#                                                   French English (UK)
# 0                                     Ferraille INOX 304          NaN
# 1                                             Abandonner          NaN
# 2                  Déchets d'ACIER INOXYDABLE FERRITIQUE          NaN
# 3                                      Carton à recycler          NaN
# 4                                   Plastique à recycler          NaN
# ...                                                  ...          ...
# 23623                                                NaN          NaN
# 23624  Vitrine buffet réfrigéré à paroi droite avec t...          NaN
# 23625  Vitrine buffet droit réfrigéré avec thermo-rid...          NaN
# 23626  Thermomètre analogique rond, échelle 0-120º Mo...          NaN
# 23627                                Jus bio pour foires          NaN
#
# [23628 rows x 5 columns]
# Converted: Hornos.xlsx to Hornos.csv in the 'output' folder
# Table after replacing 'Unnamed' columns with spaces for Hornos_coccion_acelerada.xlsx:
#        ItemCode                                           ItemName  \
# 0      0CHAT001                                  Chatarra INOX 304
# 1      0CHAT002                                           Chatarra
# 2      0CHAT003                            Chatarra INOX FERRITICO
# 3      0CHAT005                               Carton para reciclar
# 4      0CHAT006                             Plástico para reciclar
# ...         ...                                                ...
# 23623  VMRA64GN  Vitrina Buffet refrigerada recta mural  con pu...
# 23624  VMRT03GN  Vitrina Buffet refrigerada recta mural con ter...
# 23625  VMRT04GN  Vitrina Buffet refrigerada recta mural  con te...
# 23626  VRE00016  Termómetro analógico redondo, escala 0-120º  M...
# 23627  ZUMFERIA                       Zumos ecologicos para ferias
#
#                                                  English  \
# 0                                         Scrap INOX 304
# 1                                                  Scrap
# 2                         FERRITIC STAINLESS STEEL scrap
# 3                                   Cardboard to recycle
# 4                                  Plastic for recycling
# ...                                                  ...
# 23623                                                NaN
# 23624  Refrigerated straight wall buffet display cabi...
# 23625  Refrigerated straight wall buffet display cabi...
# 23626  Round analog thermometer, scale 0-120º Mod. IM...
# 23627                           Organic juices for fairs
#
#                                                   French English (UK)
# 0                                     Ferraille INOX 304          NaN
# 1                                             Abandonner          NaN
# 2                  Déchets d'ACIER INOXYDABLE FERRITIQUE          NaN
# 3                                      Carton à recycler          NaN
# 4                                   Plastique à recycler          NaN
# ...                                                  ...          ...
# 23623                                                NaN          NaN
# 23624  Vitrine buffet réfrigéré à paroi droite avec t...          NaN
# 23625  Vitrine buffet droit réfrigéré avec thermo-rid...          NaN
# 23626  Thermomètre analogique rond, échelle 0-120º Mo...          NaN
# 23627                                Jus bio pour foires          NaN
#
# [23628 rows x 5 columns]
# Converted: Hornos_coccion_acelerada.xlsx to Hornos_coccion_acelerada.csv in the 'output' folder
# Table after replacing 'Unnamed' columns with spaces for Regeneradores.xlsx:
#        ItemCode                                           ItemName  \
# 0      0CHAT001                                  Chatarra INOX 304
# 1      0CHAT002                                           Chatarra
# 2      0CHAT003                            Chatarra INOX FERRITICO
# 3      0CHAT005                               Carton para reciclar
# 4      0CHAT006                             Plástico para reciclar
# ...         ...                                                ...
# 23623  VMRA64GN  Vitrina Buffet refrigerada recta mural  con pu...
# 23624  VMRT03GN  Vitrina Buffet refrigerada recta mural con ter...
# 23625  VMRT04GN  Vitrina Buffet refrigerada recta mural  con te...
# 23626  VRE00016  Termómetro analógico redondo, escala 0-120º  M...
# 23627  ZUMFERIA                       Zumos ecologicos para ferias
#
#                                                  English  \
# 0                                         Scrap INOX 304
# 1                                                  Scrap
# 2                         FERRITIC STAINLESS STEEL scrap
# 3                                   Cardboard to recycle
# 4                                  Plastic for recycling
# ...                                                  ...
# 23623                                                NaN
# 23624  Refrigerated straight wall buffet display cabi...
# 23625  Refrigerated straight wall buffet display cabi...
# 23626  Round analog thermometer, scale 0-120º Mod. IM...
# 23627                           Organic juices for fairs
#
#                                                   French English (UK)
# 0                                     Ferraille INOX 304          NaN
# 1                                             Abandonner          NaN
# 2                  Déchets d'ACIER INOXYDABLE FERRITIQUE          NaN
# 3                                      Carton à recycler          NaN
# 4                                   Plastique à recycler          NaN
# ...                                                  ...          ...
# 23623                                                NaN          NaN
# 23624  Vitrine buffet réfrigéré à paroi droite avec t...          NaN
# 23625  Vitrine buffet droit réfrigéré avec thermo-rid...          NaN
# 23626  Thermomètre analogique rond, échelle 0-120º Mo...          NaN
# 23627                                Jus bio pour foires          NaN
#
# [23628 rows x 5 columns]
# Converted: Regeneradores.xlsx to Regeneradores.csv in the 'output' folder
# Table after replacing 'Unnamed' columns with spaces for Tabla valores iSeal.xlsx:
#    Configuración envasadora
# 0                    Modelo  iSeal  iVac
# 1                  TIS8xxxx      3    14
# 2                  TIM10xxx      5    24
# 3                  TIM16xxx      5    31
# 4                  TIM20xxx      5    53
# 5                  TIL20xxx      7    20
# 6                  FSS20xxx      7    13
# 7                  FSS40xxx      7    27
# 8                  FSM40xxx      9    17
# 9                  FSM63xxx      9    23
# 10                 FSL63xxx     10    13
# 11                FSL100xxx     10    19
# Converted: Tabla valores iSeal.xlsx to Tabla valores iSeal.csv in the 'output' folder
# Table after replacing 'Unnamed' columns with spaces for Video tutoriales Youtube.xlsx:
#     Número                                   Motivo del video  \
# 0      1.0                               Cambio aceite Tekvac
# 1      2.0                              Puesta a punto Tekvac
# 2      3.0                                    Calibrar Tekvac
# 3      4.0                                Limpieza Mychef MK1
# 4      5.0                  Tutorial control remoto BAKE/COOK
# 5      6.0                       Tutorial uso BAKERSHOP/SNACK
# 6      7.0                              Tutorial uso GoSensor
# 7      8.0                               Tutorial uso iSENSOR
# 8      9.0                             Tutorial uso BAKE/COOK
# 9     10.0                     Cambio aceite iSensor/GoSensor
# 10    11.0                                  Calibrar GoSensor
# 11    12.0                                   Calibrar iSensor
# 12    13.0                    Conectar envasadora a impresora
# 13    14.0                         Test relés BAKERSHOP/SNACK
# 14    15.0                               Test relés BAKE/COOK
# 15    16.0                   Mychef Cook - Menú configuración
# 16    17.0        goSensor - Ciclos y horas de funcionamiento
# 17    18.0                        Mychef Cook - Test de relés
# 18    19.0                       Mychef Cook - Acceso control
# 19    20.0         iSensor - Ciclos y horas de funcionamiento
# 20    21.0                    iSensor - Menú servicio técnico
# 21    22.0                    iSensor - Acceso partes activas
# 22    23.0                    After sales training (May 2021)
# 23    30.0              Test de relés en Mychef iCook o iBake
# 24    31.0   Comprobación estanquidad de la cámara en iSensor
# 25    32.0  Comprobación estanquidad de la cámara en goSensor
# 26    33.0  Comprobación del caudal de agua en Cook o Bake...
# 27    34.0  Comprobación del caudal de agua necesario en i...
# 28    35.0                        Cómo desmontar cierre QUICK
# 29    36.0                       Cómo desmontar altavoz QUICK
# 30    37.0                            Barra soldadura iSensor
# 31    38.0                           Barra soldadura goSensor
# 32    39.0                              Apertura Tapa iSensor
# 33    40.0                             Apertura tapa goSensor
# 34     NaN                                                NaN
#
#                        Enlace video Youtube ESP  \
# 0   https://www.youtube.com/watch?v=dE8ZRsuji18
# 1   https://www.youtube.com/watch?v=_iJgd4TY4Vc
# 2   https://www.youtube.com/watch?v=ljmHC2aIoUw
# 3   https://www.youtube.com/watch?v=azQoiOR9OXY
# 4   https://www.youtube.com/watch?v=Bp2iVJG9odU
# 5   https://www.youtube.com/watch?v=ZOHjm7nqttI
# 6   https://www.youtube.com/watch?v=9dLcwgcdUeI
# 7   https://www.youtube.com/watch?v=R4IwKgS03R0
# 8   https://www.youtube.com/watch?v=3LKEfWNuO8s
# 9   https://www.youtube.com/watch?v=SvK0RMZ04KA
# 10  https://www.youtube.com/watch?v=5ORw7SaHvgg
# 11  https://www.youtube.com/watch?v=BRBbr7BApcA
# 12  https://www.youtube.com/watch?v=j-OOQWO0Fm8
# 13  https://www.youtube.com/watch?v=v-JnxO9ALD8
# 14  https://www.youtube.com/watch?v=biWr1n3EmbI
# 15                 https://youtu.be/G7C9LeCHevo
# 16                 https://youtu.be/5_66GynNsMQ
# 17                 https://youtu.be/94LMtPT5CmY
# 18                 https://youtu.be/oOAOLMjJS3Q
# 19                 https://youtu.be/n_v8lGb-7bU
# 20                 https://youtu.be/elMHOhyrM8c
# 21                 https://youtu.be/9ipaQuus6UQ
# 22                 https://youtu.be/2FEx-N2aux8
# 23                 https://youtu.be/4NvFxr3TW0U
# 24                 https://youtu.be/cLFxy1mRazg
# 25                 https://youtu.be/f7arIgDViSs
# 26                 https://youtu.be/oypSYO7gDZs
# 27                 https://youtu.be/XLQ8QaFWqVM
# 28                 https://youtu.be/dLLOo_p1Eh4
# 29                 https://youtu.be/Jfdnk9FzulY
# 30                 https://youtu.be/6EymwXU2nDs
# 31                 https://youtu.be/PSeoxZvDE9U
# 32                 https://youtu.be/UTx8KZ3bVEc
# 33                 https://youtu.be/4O7Sg6HHajg
# 34                                          NaN
#
#                         Enlace video Youtube EN  \
# 0                                             -
# 1                                             -
# 2                                             -
# 3                                             -
# 4   https://www.youtube.com/watch?v=pcSupTaRrYI
# 5   https://www.youtube.com/watch?v=ucCFqV4ZADk
# 6   https://www.youtube.com/watch?v=K0MafGp1DRo
# 7   https://www.youtube.com/watch?v=n2dIgKuuXUQ
# 8   https://www.youtube.com/watch?v=o1l6Ew8lwVc
# 9   https://www.youtube.com/watch?v=V395p9Ac6j0
# 10  https://www.youtube.com/watch?v=frkpxy9bw9c
# 11  https://www.youtube.com/watch?v=8XTHIQgRF2Q
# 12  https://www.youtube.com/watch?v=JvNC3-KkXQQ
# 13  https://www.youtube.com/watch?v=v3qInrBE_Tw
# 14  https://www.youtube.com/watch?v=Ey3dXLr44HY
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                                          NaN
# 33                                          NaN
# 34                                          NaN
#
#                         Enlace video Youtube FR    Estado  \
# 0                                             -   Publico
# 1                                             -   Publico
# 2                                             -   Publico
# 3                                             -   Publico
# 4   https://www.youtube.com/watch?v=HT7Z1ZM58PA   Publico
# 5   https://www.youtube.com/watch?v=Kod0xt0bMRc   Publico
# 6   https://www.youtube.com/watch?v=K0MafGp1DRo   Publico
# 7   https://www.youtube.com/watch?v=n2dIgKuuXUQ   Publico
# 8   https://www.youtube.com/watch?v=Yk5UYNUYACI   Publico
# 9   https://www.youtube.com/watch?v=CUrjy3ICgMg   Publico
# 10  https://www.youtube.com/watch?v=tzUB8XOefBU   Publico
# 11  https://www.youtube.com/watch?v=jOtxkhCkowA   Publico
# 12  https://www.youtube.com/watch?v=00rbsrxszf4   Publico
# 13  https://www.youtube.com/watch?v=yCjsME3s_HQ   Publico
# 14  https://www.youtube.com/watch?v=o7X7j1WUpVQ   Publico
# 15                                          NaN    Oculto
# 16                                          NaN    Oculto
# 17                                          NaN    Oculto
# 18                                          NaN    Oculto
# 19                                          NaN    Oculto
# 20                                          NaN    Oculto
# 21                                          NaN    Oculto
# 22                                          NaN    Oculto
# 23                                          NaN    Oculto
# 24                                          NaN    Oculto
# 25                                          NaN    Oculto
# 26                                          NaN    Oculto
# 27                                          NaN    Oculto
# 28                                          NaN    Oculto
# 29                                          NaN    Oculto
# 30                                          NaN    Oculto
# 31                                          NaN    Oculto
# 32                                          NaN    Oculto
# 33                                          NaN    Oculto
# 34                                          NaN  Deseable
#
#                     Máquina
# 0                    Tekvac
# 1                    Tekvac
# 2                    Tekvac
# 3                Mychef MK1
# 4   BAKE/COOK PRO/MASTER/UP
# 5           BAKERSHOP/SNACK
# 6                  GoSensor
# 7                   iSensor
# 8                 BAKE/COOK
# 9          goSensor/iSensor
# 10         goSensor/iSensor
# 11                  iSensor
# 12                  iSensor
# 13          BAKERSHOP/SNACK
# 14                BAKE/COOK
# 15                BAKE/COOK
# 16                 GoSensor
# 17                BAKE/COOK
# 18                BAKE/COOK
# 19                  iSensor
# 20                  iSensor
# 21                  iSensor
# 22              Webinar ENG
# 23              iCook/iBake
# 24                  iSensor
# 25                 goSensor
# 26                BAKE/COOK
# 27              iCook/iBake
# 28                    Quick
# 29                    Quick
# 30                  iSensor
# 31                 goSensor
# 32                  iSensor
# 33                 goSensor
# 34                      NaN
# Converted: Video tutoriales Youtube.xlsx to Video tutoriales Youtube.csv in the 'output' folder

# %%
# Show all converted files
converted_files
# Out:
# ['Abatidores.csv',
#  'Envasadoras.csv',
#  'Hornos.csv',
#  'Hornos_coccion_acelerada.csv',
#  'Regeneradores.csv',
#  'Tabla valores iSeal.csv',
#  'Video tutoriales Youtube.csv']
